# %%
import numpy as np
import tensorflow as tf

# %%
import time

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
shape=5000

# %%
np_array = np.random.uniform(size=[shape,shape])

# %%
start = time.time()

for i in range(10):
  np.matmul(np_array, np_array)

end =time.time()
time_period = end - start
print(f'{time_period} seconds')
# Out:
# 56.86950969696045 seconds

# %%
tf_array =tf.random.uniform(shape=[shape,shape])

# %%
start= time.time()
for i in range (10):
  tf.matmul(tf_array, tf_array)
end = time.time()
time_period = end - start
print(f'{time_period} seconds')
# Out:
# 0.1534581184387207 seconds
